# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Dataset: Airbnb London Listings

df = pd.read_csv(r"C:\Users\ADITHYA A M\Downloads\airbnb_london.csv")
print(f"Loaded: {len(df)} listings")
print(df.describe().round(1))
# Out:
# Loaded: 2500 listings
#         price  minimum_nights  number_of_reviews  availability_365  \
# count  2500.0          2500.0             2500.0            2500.0
# mean    148.6            14.8              147.9             183.7
# std     110.9             8.4               86.3             105.5
# min      20.5             1.0                0.0               0.0
# 25%      71.7             8.0               74.0              92.0
# 50%     117.5            15.0              145.0             182.0
# 75%     188.9            22.0              222.2             277.0
# max    1032.4            29.0              299.0             364.0
#
#        reviews_per_month
# count             2500.0
# mean                 2.0
# std                  2.0
# min                  0.0
# 25%                  0.6
# 50%                  1.4
# 75%                  2.8
# max                 15.2

# %%
# Task 1 — Histogram
# Price distribution by room type

# Filter to required room types only
df_hist = df_cap[df_cap['room_type'].isin(['Entire home/apt', 'Private room'])]

# Median prices
median_entire = df_hist[df_hist['room_type'] == 'Entire home/apt']['price'].median()
median_private = df_hist[df_hist['room_type'] == 'Private room']['price'].median()

# Create histogram
fig = px.histogram(
    df_hist,
    x='price',
    color='room_type',
    barmode='overlay',
    opacity=0.6,
    nbins=40,
    color_discrete_map={
        'Entire home/apt': '#1f77b4',
        'Private room': '#ff7f0e'
    },
    title='Right-Skewed Price Distribution: Entire Homes Cost Substantially More Than Private Rooms'
)

# Median reference lines
fig.add_vline(
    x=median_entire,
    line_color='#1f77b4',
    line_dash='dash',
    annotation_text=f'Entire home median: £{median_entire:.0f}',
    annotation_position='top left'
)

fig.add_vline(
    x=median_private,
    line_color='#ff7f0e',
    line_dash='dash',
    annotation_text=f'Private room median: £{median_private:.0f}',
    annotation_position='top right'
)

# Annotation for capped outliers
fig.add_annotation(
    text=f'Prices capped at 95th percentile (£{p95:.0f})',
    xref='paper',
    yref='paper',
    x=1,
    y=1.12,
    showarrow=False
)

# Layout improvements
fig.update_layout(
    xaxis_title='Price per Night (£)',
    yaxis_title='Number of Listings',
    legend_title='Room Type'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 # Task 1 — Histogram
#       2 # Price distribution by room type
#       3
#       4 # Filter to required room types only
# ----> 5 df_hist = df_cap[df_cap['room_type'].isin(['Entire home/apt', 'Private room'])]
#       7 # Median prices
#       8 median_entire = df_hist[df_hist['room_type'] == 'Entire home/apt']['price'].median()
#
# NameError: name 'df_cap' is not defined
